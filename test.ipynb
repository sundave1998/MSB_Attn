# %%
import os


data_path = "/media/ybsun/Storage/Long-Data-Collections-main/processed/"

paths = os.path.join(data_path, "*.arrow")

paths = os.listdir(data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 data_path = "/media/ybsun/Storage/Long-Data-Collections-main/processed"
#       6 paths = os.path.join(data_path, "*.arrow")
# ----> 8 paths = os.listdir(data_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/ybsun/Storage/Long-Data-Collections-main/processed'

# %%
print(paths)
# Out:
# /media/ybsun/Storage/Long-Data-Collections-main/processed/*.arrow
